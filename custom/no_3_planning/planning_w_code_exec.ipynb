# %% [markdown]
# # M5 Agentic AI - Customer Service Agent
#
# ## 1. Introduction
#
# As Andrew explained in the lecture, *planning with code execution* means letting the LLM **write code that becomes the plan itself**.
# Compared to plain-text or JSON-based plans, this approach is more expressive and flexible: the code not only documents the steps but can also execute them directly.
#
# In this lab, you will implement this design pattern in practice.
# Instead of asking the LLM to output a plan in JSON format and then manually executing each step, we will allow it to **write Python code** that directly captures multiple steps of a plan. By executing this code, we can carry out complex queries automatically.
#
# To make things concrete, we simulate a **sunglasses store** with an **inventory** of products and a set of **transactions** (sales, returns, balance updates). This example shows how the LLM can generate code to query or update records, demonstrating the flexibility of this pattern.
#
# ### 1.1 Lab Overview
# We will:
# 1. Create simple **inventory** and **transaction** datasets.
# 2. Build a **schema block** describing the data.
# 3. Prompt the LLM to **write a plan as Python code** (with comments explaining each step).
# 4. Execute the code in a sandbox to obtain the answer.
#
# ### 1.2 Learning Outcomes
#
# By the end of this lab, you will be able to:
#
# - **Explain** why letting the model write code (instead of JSON or plain text plans) enables richer, more flexible planning.
# - **Prompt** an LLM to produce Python code with step-by-step comments that both documents and executes the plan.
# - **Run** the generated code safely in a sandbox and interpret the results.
#
# This illustrates how *Code as Action* can outperform brittle tool chains and JSON-based planning approaches.

# %% [markdown]
# ## 2. Setup

# %%
# ==== Imports ====
from __future__ import annotations
import json
from dotenv import load_dotenv
# from openai import OpenAI
import re, io, sys, traceback, json
from typing import Any, Dict, Optional
from tinydb import Query, where

# Utility modules
import utils      # helper functions for prompting/printing
import inv_utils  # functions for inventory, transactions, schema building, and TinyDB seeding

load_dotenv()
# client = OpenAI()
# Out:
# True

# %%
from google import genai
from google.genai import types
import os

# Configure the client and tools
gemini_api_key = os.getenv("GEMINI_API_KEY")
# gemini_api_key = os.getenv("GEMINI_API_KEY_2")

client = genai.Client(api_key=gemini_api_key)

# %% [markdown]
# In the `inv_utils` module, we have functions like:
#
# - `create_inventory()` – builds the sunglasses inventory.
# - `create_transactions()` – builds the initial transaction log.
# - `seed_db()` – loads both inventory and transactions into a JSON-backed store.
# - `build_schema_block()` – generates a schema description used in the prompt.
# - Helpers like `get_current_balance()` and `next_transaction_id()` – let the LLM handle consistent updates across inventory and transactions.

# %% [markdown]
# ### 2.1 Create Example Tables
#
# We will now create two small tables for the sunglasses store simulation, using **[TinyDB](https://tinydb.readthedocs.io/)** — a lightweight document-oriented database written in pure Python.
# TinyDB stores data as JSON documents and is well-suited for small applications or prototypes, since it requires no server setup and allows you to query and update data easily.
#
# The two tables are:
#
# - **`inventory_tbl`**: contains product details such as name, item ID, description, quantity in stock, and price.
# - **`transactions_tbl`**: starts with an opening balance and will later track purchases, returns, and adjustments.
#
# You will generate these tables using helper functions in `inv_utils`, and then preview the first few rows below.

# %%
db, inventory_tbl, transactions_tbl = inv_utils.seed_db()

# %% [markdown]
# Now, you can inspect the records in each table by printing them as formatted JSON:

# %%
utils.print_html(json.dumps(inventory_tbl.all(), indent=2), title="Inventory Table")
utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 23,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:44:01.482957&quot;
#   }
# ]</code></pre></div>

# %% [markdown]
# As you can see above, the schemas of each table are as follows:
#
# <div style="border:1px solid #BFDBFE; border-left:6px solid #3B82F6; background:#EFF6FF; border-radius:6px; padding:16px; font-family:system-ui,-apple-system,Segoe UI,Roboto,Ubuntu,Cantarell,Noto Sans,sans-serif; line-height:1.6; color:#1E3A8A;">
#
#   <h4 style="margin-top:0; color:#1E40AF;">Inventory Table (<code>inventory_tbl</code>)</h4>
#   <ul>
#     <li><strong>item_id</strong> (string): Unique product identifier (e.g., SG001).</li>
#     <li><strong>name</strong> (string): Style of sunglasses (e.g., Aviator, Round).</li>
#     <li><strong>description</strong> (string): Text description of the product.</li>
#     <li><strong>quantity_in_stock</strong> (int): Current stock available.</li>
#     <li><strong>price</strong> (float): Price in USD.</li>
#   </ul>
#   <h4 style="margin-top:1em; color:#1E40AF;">Transactions Table (<code>transactions_tbl</code>)</h4>
#   <ul>
#     <li><strong>transaction_id</strong> (string): Unique identifier (e.g., TXN001).</li>
#     <li><strong>customer_name</strong> (string): Name of the customer, or <code>OPENING_BALANCE</code> for initial entry.</li>
#     <li><strong>transaction_summary</strong> (string): Short description of the transaction.</li>
#     <li><strong>transaction_amount</strong> (float): Amount of money for this transaction.</li>
#     <li><strong>balance_after_transaction</strong> (float): Running balance after applying the transaction.</li>
#     <li><strong>timestamp</strong> (string): ISO-8601 formatted date/time of the transaction.</li>
#   </ul>
# </div>

# %% [markdown]
# ## Planning with Code Execution

# %% [markdown]
# ### 2.1. The plan
#
# Once the schema is clear, you’ll build the **prompt** that instructs the model to *plan by writing code* and then execute that code. As Andrew emphasized, the code is the plan: the model explains each step in comments, then carries it out. Your prompt below also makes the model self-decide whether the request is read-only or a state change, and it enforces safe execution (no I/O, no network, TinyDB Query only, consistent mutations).

# %%
PROMPT = """You are a senior data assistant. PLAN BY WRITING PYTHON CODE USING TINYDB.

Database Schema & Samples (read-only):
{schema_block}

Execution Environment (already imported/provided):
- Variables: db, inventory_tbl, transactions_tbl  # TinyDB Table objects
- Helpers: get_current_balance(tbl) -> float, next_transaction_id(tbl, prefix="TXN") -> str
- Natural language: user_request: str  # the original user message

PLANNING RULES (critical):
- Derive ALL filters/parameters from user_request (shape/keywords, price ranges "under/over/between", stock mentions,
  quantities, buy/return intent). Do NOT hard-code values.
- Build TinyDB queries dynamically with Query(). If a constraint isn't in user_request, don't apply it.
- Be conservative: if intent is ambiguous, do read-only (DRY RUN).

TRANSACTION POLICY (hard):
- Do NOT create aggregated multi-item transactions.
- If the request contains multiple items, create a separate transaction row PER ITEM.
- For each item:
  - compute its own line total (unit_price * qty),
  - insert ONE transaction with that amount,
  - update balance sequentially (balance += line_total),
  - update the item’s stock.
- If any requested item lacks sufficient stock, do NOT mutate anything; reply with STATUS="insufficient_stock".

HUMAN RESPONSE REQUIREMENT (hard):
- You MUST set a variable named `answer_text` (type str) with a short, customer-friendly sentence (1–2 lines).
- This sentence is the only user-facing message. No dataframes/JSON, no boilerplate disclaimers.
- If nothing matches, politely say so and offer a nearby alternative (closest style/price) or a next step.

ACTION POLICY:
- If the request clearly asks to change state (buy/purchase/return/restock/adjust):
    ACTION="mutate"; SHOULD_MUTATE=True; perform the change and write a matching transaction row.
  Otherwise:
    ACTION="read"; SHOULD_MUTATE=False; simulate and explain briefly as a dry run (in logs only).

FAILURE & EDGE-CASE HANDLING (must implement):
- Do not capture outer variables in Query.test. Pass them as explicit args.
- Always set a short `answer_text`. Also set a string `STATUS` to one of:
  "success", "no_match", "insufficient_stock", "invalid_request", "unsupported_intent".
- no_match: No items satisfy the filters → suggest the closest in style/price, or invite a different range.
- insufficient_stock: Item found but stock < requested qty → state available qty and offer the max you can fulfill.
- invalid_request: Unable to parse essential info (e.g., quantity for a purchase/return) → ask for the missing piece succinctly.
- unsupported_intent: The action is outside the store’s capabilities → provide the nearest supported alternative.
- In all cases, keep the tone helpful and concise (1–2 sentences). Put technical details (e.g., ACTION/DRY RUN) only in stdout logs.

OUTPUT CONTRACT:
- Return ONLY executable Python between these tags (no extra text):
  <execute_python>
  # your python
  </execute_python>

CODE CHECKLIST (follow in code):
1) Parse intent & constraints from user_request (regex ok).
2) Build TinyDB condition incrementally; query inventory_tbl.
3) If mutate: validate stock, update inventory, insert a transaction (new id, amount, balance, timestamp).
4) ALWAYS set:
   - `answer_text` (human sentence, required),
   - `STATUS` (see list above).
   Also print a brief log to stdout, e.g., "LOG: ACTION=read DRY_RUN=True STATUS=no_match".
5) Optional: set `answer_rows` or `answer_json` if useful, but `answer_text` is mandatory.

TONE EXAMPLES (for `answer_text`):
- success: "Yes, we have our Classic sunglasses, a round frame, for $60."
- no_match: "We don’t have round frames under $100 in stock right now, but our Moon round frame is available at $120."
- insufficient_stock: "We only have 1 pair of Classic left; I can reserve that for you."
- invalid_request: "I can help with that—how many pairs would you like to purchase?"
- unsupported_intent: "We can’t refurbish frames, but I can suggest similar new models."

Constraints:
- Use TinyDB Query for filtering. Standard library imports only if needed.
- Keep code clear and commented with numbered steps.

User request:
{question}
"""

# %% [markdown]
# ### 2.2 From Prompt to Code (Planning in Code)
#
# Let’s generate code that **is the plan**.
#
# Instead of asking the model to output a plan in JSON and running it step-by-step with many tiny tools, let’s have it **write Python that encodes the whole plan** (e.g., “filter this, then compute that, then update this row”). The function `generate_llm_code`:
#
# 1. **Builds a live schema** from `inventory_tbl` and `transactions_tbl` so the model sees real fields, types, and examples.
# 2. **Formats the prompt** with that schema plus the user’s question.
# 3. **Calls the model** to produce a **plan-with-code** response — typically an `<execute_python>...</execute_python>` block whose body contains the step-by-step logic.
# 4. **Returns the full response** (including the plan and the code).
#    *We don’t execute anything in this step.*
#
# Why this pattern? Let’s leverage Python/TinyDB as a rich toolbox the model already “knows,” so it can compose multi-step solutions directly in code instead of relying on a growing set of bespoke tools. We’ll extract and run the code in a later step.

# %%
# ---------- 1) Code generation ----------
def generate_llm_code(
    prompt: str,
    *,
    inventory_tbl,
    transactions_tbl,
    model: str = "gemini-2.5-flash",
    temperature: float = 0.2,
) -> str:
    """
    Ask the LLM to produce a plan-with-code response.
    Returns the FULL assistant content (including surrounding text and tags).
    The actual code extraction happens later in execute_generated_code.
    """
    schema_block = inv_utils.build_schema_block(inventory_tbl, transactions_tbl)
    prompt = PROMPT.format(schema_block=schema_block, question=prompt)

    # resp = client.chat.completions.create(
    #     model=model,
    #     temperature=temperature,
    #     messages=[
    #         {
    #             "role": "system",
    #             "content": "You write safe, well-commented TinyDB code to handle data questions and updates."
    #         },
    #         {"role": "user", "content": prompt},
    #     ],
    # )
    # content = resp.choices[0].message.content or ""
    

    resp = client.models.generate_content(
        model=model,
        # config=types.GenerateContentConfig(
        #     system_instruction="You write safe, well-commented TinyDB code to handle data questions and updates."),
        contents=prompt
    )
    content = resp.text or ""

    return content

# %% [markdown]
# ### 2.3 Try a Sample Prompt (Planning-in-Code)
#
# We’ll use the same prompt Andrew used in the lecture:
#
# > **Prompt:** “Do you have any round sunglasses in stock that are under $100?”
#
# Before generating any code, let’s manually inspect the TinyDB tables to see if there are truly *round* frames (word-only match) and what their prices look like. Run the next cell to preview the inventory and highlight items that match the word-only “round” filter.

# %%
Item = Query()                    # Create a Query object to reference fields (e.g., Item.name, Item.description)

# Search the inventory table for documents where either the description OR the name
# contains the word "round" (case-insensitive). The check is done inline:
# - (v or "") ensures we handle None by converting it to an empty string
# - .lower() normalizes case
# - " round " enforces a crude word boundary (won't match "wraparound")
round_sunglasses = inventory_tbl.search(
    (Item.description.test(lambda v: " round " in ((v or "").lower()))) |
    (Item.name.test(        lambda v: " round " in ((v or "").lower())))
)

# Render the results as formatted JSON in the notebook UI
utils.print_html(json.dumps(round_sunglasses, indent=2), title="Inventory Status: Round Sunglasses")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Status: Round Sunglasses</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>

# %% [markdown]
# Great — we do have round frames available. From our manual inspection, there are two round styles in stock, but only **one** is **under \$100**. Therefore, the item that satisfies the requirement is:
#
# ````python
# {
#   "item_id": "SG005",
#   "name": "Classic",
#   "description": "Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.",
#   "quantity_in_stock": 10,
#   "price": 60
# }
# ````
#
# Now let’s ask the model to **generate a plan in code** that answers Andrew’s prompt (no execution yet).

# %%
# Andrew's prompt from the lecture
prompt_round = "Do you have any round sunglasses in stock that are under $100?"

# Generate the plan-as-code (FULL content; may include <execute_python> tags)
full_content_round = generate_llm_code(
    prompt_round,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    model="gemini-2.5-flash",
    temperature=1.0,
)

# Inspect the LLM’s plan + code (no execution here)
utils.print_html(full_content_round, title="Plan with Code (Full Response)")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan with Code (Full Response)</div><pre><code>&lt;execute_python&gt;
# import re
# from tinydb import Query
# from datetime import datetime
#
# # 1. Initialize Query object for inventory_tbl
# Item = Query()
#
# # Parse intent and constraints from user_request
# # Keywords for &quot;round&quot; style
# round_keywords = [&quot;round&quot;]
# # Price constraint
# price_max = 100
#
# # Build TinyDB condition incrementally
# # Condition for round style (checking both name and description)
# round_condition = None
# for keyword in round_keywords:
#     pattern = r&#x27;(?i)\b&#x27; + re.escape(keyword) + r&#x27;\b&#x27; # case-insensitive whole word match
#     current_keyword_condition = (Item.name.search(pattern) | Item.description.search(pattern))
#     if round_condition is None:
#         round_condition = current_keyword_condition
#     else:
#         round_condition |= current_keyword_condition # Use OR for multiple keywords (if any match)
#
# # Condition for price under $100
# price_condition = (Item.price &lt; price_max)
#
# # Combine all conditions with AND
# final_query = round_condition &amp; price_condition if round_condition else price_condition
#
# # 2. Query inventory_tbl
# matched_items = inventory_tbl.search(final_query)
#
# # Prepare variables for output
# answer_text = &quot;&quot;
# STATUS = &quot;&quot;
# ACTION = &quot;read&quot;
# SHOULD_MUTATE = False
#
# if matched_items:
#     STATUS = &quot;success&quot;
#     # Prioritize items with stock
#     available_items = [item for item in matched_items if item.get(&#x27;quantity_in_stock&#x27;, 0) &gt; 0]
#     if available_items:
#         # Sort by price ascending to suggest the cheapest if multiple
#         available_items.sort(key=lambda x: x[&#x27;price&#x27;])
#         # Taking the first matching item for the answer text
#         first_match = available_items[0]
#         answer_text = f&quot;Yes, we have our {first_match[&#x27;name&#x27;]} sunglasses, a round frame, for ${first_match[&#x27;price&#x27;]}.&quot;
#     else:
#         STATUS = &quot;no_match&quot; # All matched items are out of stock
#         answer_text = &quot;We found round frames under $100, but they are currently out of stock. Would you like to check other styles?&quot;
# else:
#     STATUS = &quot;no_match&quot;
#     # If no items match the exact criteria, try to find a close alternative.
#     # First, find any round frames regardless of price.
#     all_round_frames = []
#     if round_condition:
#         all_round_frames = inventory_tbl.search(round_condition)
#         all_round_frames = [item for item in all_round_frames if item.get(&#x27;quantity_in_stock&#x27;, 0) &gt; 0]
#
#     if all_round_frames:
#         # Suggest the cheapest round frame, even if it&#x27;s over $100
#         all_round_frames.sort(key=lambda x: x[&#x27;price&#x27;])
#         closest_match = all_round_frames[0]
#         answer_text = f&quot;We don’t have round frames under ${price_max} in stock right now, but our {closest_match[&#x27;name&#x27;]} round frame is available at ${closest_match[&#x27;price&#x27;]}.&quot;
#     else:
#         # If no round frames at all, suggest other styles under $100
#         under_100_items = inventory_tbl.search(Item.price &lt; price_max)
#         under_100_items = [item for item in under_100_items if item.get(&#x27;quantity_in_stock&#x27;, 0) &gt; 0]
#         if under_100_items:
#             under_100_items.sort(key=lambda x: x[&#x27;price&#x27;])
#             cheapest_item = under_100_items[0]
#             answer_text = f&quot;We don’t have any round frames, but we do have the {cheapest_item[&#x27;name&#x27;]} style for ${cheapest_item[&#x27;price&#x27;]}.&quot;
#         else:
#             answer_text = &quot;We don&#x27;t have any round frames or any sunglasses under $100 in stock at the moment. Would you like to browse other options?&quot;
#
# # Log for internal use
# print(f&quot;LOG: ACTION={ACTION} DRY_RUN=True STATUS={STATUS}&quot;)
#
# # Ensure answer_text is set per contract.
# # No other variables like answer_rows or answer_json needed for this read-only simple query.
# &lt;/execute_python&gt;</code></pre></div>

# %% [markdown]
# ### 2.4. Define the executor function (run a given plan)
#
# Now we’ll define the function that **takes a plan produced by the model and runs it** safely:
#
# - Step 1) It **accepts either** the full LLM response (with `<execute_python>…</execute_python>`) **or** raw Python code.
# - Step 2) It **extracts** the executable block when needed.
# - Step 3) It runs the code in a **controlled namespace** (TinyDB tables + safe helpers only).
# - Step 4) It captures **stdout**, **errors**, and the model-set answer variables (`answer_text`, `answer_rows`, `answer_json`).
# - Step 5) It renders **before/after** table snapshots to make side effects explicit.
#
# This is the “executor” that turns a **plan-as-code** into actions and a concise user-facing answer.

# %% [markdown]
# #### Explain step 3

# %% [markdown]
# 1) Accept “generated” code: <br>
# _extract_execute_block looks for <execute_python>...</execute_python> in the LLM output and returns whatever’s inside. If no tags are found it treats the whole string as Python code.
# Purpose: let the LLM return both explanation + a runnable code block, and pick out only the code.
#
# 2) Create a limited view (a “controlled namespace”): <br>
# SAFE_GLOBALS and SAFE_LOCALS are dictionaries passed into exec(...). The idea: only let the generated code see specific functions and variables you choose — e.g. Query, get_current_balance, and the DB table handles.
# Purpose (intended): simulate a sandbox by exposing a small API surface to generated code.
#
# 3) Capture stdout: <br>
# The code temporarily replaces sys.stdout with a StringIO() so any print() inside the generated code is captured instead of going to the real console. That captured text is returned as "stdout".
# Purpose: safely collect output for display/logging.
#
# 4) Run the code and catch errors: <br>
# exec(code, SAFE_GLOBALS, SAFE_LOCALS) executes the code. Exceptions are caught and converted to a traceback string returned as "error". This prevents the whole app from crashing when LLM code misbehaves.
# Purpose: fault containment and structured error reporting.
#
# 5) Extract answers & snapshots: <br>
# After execution it looks for answer_text, answer_rows, or answer_json in SAFE_LOCALS and returns them as answer. It also returns transactions_tbl.all() and inventory_tbl.all() — snapshots for inspection.
# Purpose: give the calling system structured results and view of DB state after code ran.

# %%
# --- Helper: extract code between <execute_python>...</execute_python> ---
def _extract_execute_block(text: str) -> str:
    """
    Returns the Python code inside <execute_python>...</execute_python>.
    If no tags are found, assumes 'text' is already raw Python code.
    """
    if not text:
        raise RuntimeError("Empty content passed to code executor.")
    m = re.search(r"<execute_python>(.*?)</execute_python>", text, re.DOTALL | re.IGNORECASE)
    return m.group(1).strip() if m else text.strip()


# ---------- 2) Code execution ----------
def execute_generated_code(
    code_or_content: str,
    *,
    db,
    inventory_tbl,
    transactions_tbl,
    user_request: Optional[str] = None,
) -> Dict[str, Any]:
    """
    Execute code in a controlled namespace.
    Accepts either raw Python code OR full content with <execute_python> tags.
    Returns minimal artifacts: stdout, error, and extracted answer.
    """
    # Extract code here (now centralized)
    code = _extract_execute_block(code_or_content)

    SAFE_GLOBALS = {
        "Query": Query,
        "get_current_balance": inv_utils.get_current_balance,
        "next_transaction_id": inv_utils.next_transaction_id,
        "user_request": user_request or "",
    }
    SAFE_LOCALS = {
        "db": db,
        "inventory_tbl": inventory_tbl,
        "transactions_tbl": transactions_tbl,
    }

    # Capture stdout from the executed code
    _stdout_buf, _old_stdout = io.StringIO(), sys.stdout
    sys.stdout = _stdout_buf
    err_text = None
    try:
        exec(code, SAFE_GLOBALS, SAFE_LOCALS)
    except Exception:
        err_text = traceback.format_exc()
    finally:
        sys.stdout = _old_stdout
    printed = _stdout_buf.getvalue().strip()

    # Extract possible answers set by the generated code
    answer = (
        SAFE_LOCALS.get("answer_text")
        or SAFE_LOCALS.get("answer_rows")
        or SAFE_LOCALS.get("answer_json")
    )


    return {
        "code": code,            # <- ya sin etiquetas
        "stdout": printed,
        "error": err_text,
        "answer": answer,
        "transactions_tbl": transactions_tbl.all(),  # For inspection
        "inventory_tbl": inventory_tbl.all(),  # For inspection
    }

# %% [markdown]
# You’ve checked the shelves and confirmed there’s exactly one round style under $100. Now the fun part: let’s hand the model’s plan-as-code to our executor and watch it do the work. The executor will peel out the <code><execute_python>...</execute_python></code> block, run it in a locked-down sandbox, and then show you everything that matters—what changed in the tables (before/after), any logs the plan printed, and the final, customer-friendly answer_text.

# %%
# Execute the generated plan for the round-sunglasses question
result = execute_generated_code(
    full_content_round,          # the full LLM response you generated earlier
    db=db,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    user_request=prompt_round, # e.g., "Do you have any round sunglasses in stock that are under $100?"
)

# Peek at exactly what Python the plan executed
utils.print_html(result["answer"], title="Plan Execution · Extracted Answer")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan Execution · Extracted Answer</div><pre><code>Yes, we have our Classic sunglasses, a round frame, for $60.</code></pre></div>

# %%
result
# Out:
# {'code': 'import re\nfrom tinydb import Query\nfrom datetime import datetime\n\n# 1. Initialize Query object for inventory_tbl\nItem = Query()\n\n# Parse intent and constraints from user_request\n# Keywords for "round" style\nround_keywords = ["round"]\n# Price constraint\nprice_max = 100\n\n# Build TinyDB condition incrementally\n# Condition for round style (checking both name and description)\nround_condition = None\nfor keyword in round_keywords:\n    pattern = r\'(?i)\\b\' + re.escape(keyword) + r\'\\b\' # case-insensitive whole word match\n    current_keyword_condition = (Item.name.search(pattern) | Item.description.search(pattern))\n    if round_condition is None:\n        round_condition = current_keyword_condition\n    else:\n        round_condition |= current_keyword_condition # Use OR for multiple keywords (if any match)\n\n# Condition for price under $100\nprice_condition = (Item.price < price_max)\n\n# Combine all conditions with AND\nfinal_query = round_condition & price_condition if round_condition else price_condition\n\n# 2. Query inventory_tbl\nmatched_items = inventory_tbl.search(final_query)\n\n# Prepare variables for output\nanswer_text = ""\nSTATUS = ""\nACTION = "read"\nSHOULD_MUTATE = False\n\nif matched_items:\n    STATUS = "success"\n    # Prioritize items with stock\n    available_items = [item for item in matched_items if item.get(\'quantity_in_stock\', 0) > 0]\n    if available_items:\n        # Sort by price ascending to suggest the cheapest if multiple\n        available_items.sort(key=lambda x: x[\'price\'])\n        # Taking the first matching item for the answer text\n        first_match = available_items[0]\n        answer_text = f"Yes, we have our {first_match[\'name\']} sunglasses, a round frame, for ${first_match[\'price\']}."\n    else:\n        STATUS = "no_match" # All matched items are out of stock\n        answer_text = "We found round frames under $100, but they are currently out of stock. Would you like to check other styles?"\nelse:\n    STATUS = "no_match"\n    # If no items match the exact criteria, try to find a close alternative.\n    # First, find any round frames regardless of price.\n    all_round_frames = []\n    if round_condition:\n        all_round_frames = inventory_tbl.search(round_condition)\n        all_round_frames = [item for item in all_round_frames if item.get(\'quantity_in_stock\', 0) > 0]\n    \n    if all_round_frames:\n        # Suggest the cheapest round frame, even if it\'s over $100\n        all_round_frames.sort(key=lambda x: x[\'price\'])\n        closest_match = all_round_frames[0]\n        answer_text = f"We don’t have round frames under ${price_max} in stock right now, but our {closest_match[\'name\']} round frame is available at ${closest_match[\'price\']}."\n    else:\n        # If no round frames at all, suggest other styles under $100\n        under_100_items = inventory_tbl.search(Item.price < price_max)\n        under_100_items = [item for item in under_100_items if item.get(\'quantity_in_stock\', 0) > 0]\n        if under_100_items:\n            under_100_items.sort(key=lambda x: x[\'price\'])\n            cheapest_item = under_100_items[0]\n            answer_text = f"We don’t have any round frames, but we do have the {cheapest_item[\'name\']} style for ${cheapest_item[\'price\']}."\n        else:\n            answer_text = "We don\'t have any round frames or any sunglasses under $100 in stock at the moment. Would you like to browse other options?"\n\n# Log for internal use\nprint(f"LOG: ACTION={ACTION} DRY_RUN=True STATUS={STATUS}")\n\n# Ensure answer_text is set per contract.\n# No other variables like answer_rows or answer_json needed for this read-only simple query.',
#  'stdout': 'LOG: ACTION=read DRY_RUN=True STATUS=success',
#  'error': None,
#  'answer': 'Yes, we have our Classic sunglasses, a round frame, for $60.',
#  'transactions_tbl': [{'transaction_id': 'TXN001',
#    'customer_name': 'OPENING_BALANCE',
#    'transaction_summary': 'Daily opening register balance',
#    'transaction_amount': 500.0,
#    'balance_after_transaction': 500.0,
#    'timestamp': '2025-12-21T17:44:01.482957'}],
#  'inventory_tbl': [{'item_id': 'SG001',
#    'name': 'Aviator',
#    'description': 'Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.',
#    'quantity_in_stock': 23,
#    'price': 80},
#   {'item_id': 'SG002',
#    'name': 'Wayfarer',
#    'description': 'Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.',
#    'quantity_in_stock': 6,
#    'price': 95},
#   {'item_id': 'SG003',
#    'name': 'Mystique',
#    'description': 'Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.',
#    'quantity_in_stock': 3,
#    'price': 70},
#   {'item_id': 'SG004',
#    'name': 'Sport',
#    'description': 'Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.',
#    'quantity_in_stock': 11,
#    'price': 110},
#   {'item_id': 'SG005',
#    'name': 'Classic',
#    'description': 'Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.',
#    'quantity_in_stock': 10,
#    'price': 60},
#   {'item_id': 'SG006',
#    'name': 'Moon',
#    'description': 'Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.',
#    'quantity_in_stock': 10,
#    'price': 120}]}

# %% [markdown]
# As you can see, this is the expected result based on our previous manual analysis.

# %% [markdown]
# ## 2.4 Return Two Aviator Sunglasses
#
# In the previous step we only **queried** the data, so inventory and transactions were unchanged.
# Now let’s handle a **return** scenario using the planning-in-code pattern:
# > **Request:** “Return 2 Aviator sunglasses I bought last week.”
#
# Before generating the plan, let’s **inspect the current inventory** for the *Aviator* model.

# %%
Item = Query()                    # Create a Query object to reference fields (e.g., Item.name, Item.description)

# Query: fetch all inventory rows whose 'name' is exactly "Aviator".
# Notes:
# - This is a case-sensitive equality check. "aviator" won't match.
# - If you need case-insensitive matching, consider a .test(...) or .matches(...) with re.I.
aviators = inventory_tbl.search(
    (Item.name == "Aviator")
)

# Display the matched documents in a readable JSON panel
utils.print_html(json.dumps(aviators, indent=2), title="Inventory status: Aviator sunglasses before return")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory status: Aviator sunglasses before return</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 23,
#     &quot;price&quot;: 80
#   }
# ]</code></pre></div>

# %% [markdown]
# Inventory confirms one Aviator SKU in stock — **SG001 (Aviator)**: **23** units at **$80** each. Now let's generate a plan to answer the prompt:

# %%
prompt_aviator = "Return 2 Aviator sunglasses I bought last week."

# Generate the plan-as-code (FULL content; may include <execute_python> tags)
full_content_aviator = generate_llm_code(
    prompt_aviator,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    model="gemini-2.5-flash",
    temperature=1.0,
)

# Inspect the LLM’s plan + code (no execution here)
utils.print_html(full_content_aviator, title="Plan with Code (Full Response)")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan with Code (Full Response)</div><pre><code>&lt;execute_python&gt;
# import re
# from datetime import datetime
# from tinydb import Query
#
# # TinyDB Query instance
# Item = Query()
# Transaction = Query()
#
# # 1. Initialize variables for response and control flow
# answer_text = &quot;&quot;
# STATUS = &quot;invalid_request&quot;  # Default status, will be refined
# ACTION = &quot;read&quot;
# SHOULD_MUTATE = False
#
# item_name = None
# quantity = None
# is_return = False
#
# # 2. Parse intent and constraints from user_request
# # Check for a clear &quot;return&quot; intent keyword
# return_intent_match = re.search(r&quot;\breturn\b&quot;, user_request, re.IGNORECASE)
#
# if return_intent_match:
#     is_return = True
#     ACTION = &quot;mutate&quot;
#     SHOULD_MUTATE = True
#
#     # Regex to extract quantity and item name from the request
#     # Example: &quot;Return 2 Aviator sunglasses&quot;, &quot;2 Aviator I bought&quot;
#     # Captures (quantity) and (item_name)
#     parse_match = re.search(r&quot;(\d+)\s+([a-zA-Z]+)(?:\s+sunglasses)?&quot;, user_request, re.IGNORECASE)
#
#     if parse_match:
#         try:
#             quantity = int(parse_match.group(1))
#             item_name = parse_match.group(2).strip()
#
#             # Capitalize item_name to match schema consistency (e.g., &#x27;Aviator&#x27; vs &#x27;aviator&#x27;)
#             item_name = item_name.capitalize()
#
#             if quantity &lt;= 0:
#                 STATUS = &quot;invalid_request&quot;
#                 answer_text = &quot;The quantity for a return must be a positive number.&quot;
#                 print(f&quot;LOG: ACTION={ACTION} DRY_RUN={not SHOULD_MUTATE} STATUS={STATUS}&quot;)
#             else:
#                 STATUS = &quot;success&quot; # Tentative success, will be confirmed after DB check
#         except ValueError:
#             STATUS = &quot;invalid_request&quot;
#             answer_text = &quot;I couldn&#x27;t understand the quantity you specified. Please use a valid number.&quot;
#             print(f&quot;LOG: ACTION={ACTION} DRY_RUN={not SHOULD_MUTATE} STATUS={STATUS}&quot;)
#     else:
#         # If quantity or item name could not be parsed
#         STATUS = &quot;invalid_request&quot;
#         answer_text = &quot;I couldn&#x27;t identify the item or quantity for your return. Please specify both.&quot;
#         print(f&quot;LOG: ACTION={ACTION} DRY_RUN={not SHOULD_MUTATE} STATUS={STATUS}&quot;)
# else:
#     # If the request does not clearly indicate a return
#     STATUS = &quot;unsupported_intent&quot;
#     answer_text = &quot;I can only process purchases or returns for items currently in our inventory.&quot;
#     print(f&quot;LOG: ACTION={ACTION} DRY_RUN={not SHOULD_MUTATE} STATUS={STATUS}&quot;)
#
# # Proceed with database operations only if parsing for a return was successful
# if is_return and item_name and quantity is not None and STATUS == &quot;success&quot;:
#     # 3. Build TinyDB condition for item lookup (case-insensitive name match)
#     query_condition = Item.name.test(lambda x: x.lower() == item_name.lower())
#
#     # 4. Query inventory_tbl for the specified item
#     found_items = inventory_tbl.search(query_condition)
#
#     if found_items:
#         # Assuming item names are unique, take the first match
#         target_item = found_items[0]
#         item_id = target_item[&#x27;item_id&#x27;]
#         unit_price = target_item[&#x27;price&#x27;]
#         current_stock = target_item[&#x27;quantity_in_stock&#x27;]
#
#         # 5. Perform Mutation (update inventory and record transaction)
#         if SHOULD_MUTATE:
#             # Update inventory: increase stock by the returned quantity
#             new_stock = current_stock + quantity
#             inventory_tbl.update({&#x27;quantity_in_stock&#x27;: new_stock}, query_condition)
#
#             # Record transaction: decrease store balance
#             # The value returned to the customer
#             return_value_to_customer = unit_price * quantity
#
#             current_balance = get_current_balance(transactions_tbl)
#             # Transaction amount is negative as money is paid out from the register for a return
#             transaction_amount = -return_value_to_customer
#             new_balance_after_transaction = current_balance + transaction_amount
#
#             transaction_id = next_transaction_id(transactions_tbl)
#             timestamp = datetime.now().isoformat()
#
#             transaction_summary = f&quot;Customer return of {quantity} {item_name} (Item ID: {item_id})&quot;
#             customer_name_for_transaction = &quot;Customer Return&quot; # Default name for returns
#
#             transactions_tbl.insert({
#                 &#x27;transaction_id&#x27;: transaction_id,
#                 &#x27;customer_name&#x27;: customer_name_for_transaction,
#                 &#x27;transaction_summary&#x27;: transaction_summary,
#                 &#x27;transaction_amount&#x27;: transaction_amount,
#                 &#x27;balance_after_transaction&#x27;: new_balance_after_transaction,
#                 &#x27;timestamp&#x27;: timestamp
#             })
#
#             STATUS = &quot;success&quot;
#             answer_text = f&quot;Successfully processed your return of {quantity} {item_name} sunglasses. Your account will be credited ${return_value_to_customer:.2f}. We now have {new_stock} pairs in stock.&quot;
#             print(f&quot;LOG: ACTION={ACTION} DRY_RUN={not SHOULD_MUTATE} STATUS={STATUS} Item={item_name} Quantity={quantity} NewStock={new_stock} ReturnAmount={return_value_to_customer:.2f}&quot;)
#
#     else:
#         # If the requested item for return was not found in inventory
#         STATUS = &quot;no_match&quot;
#         answer_text = f&quot;We couldn&#x27;t find &#x27;{item_name}&#x27; sunglasses in our inventory. Are you sure you bought them from us?&quot;
#         print(f&quot;LOG: ACTION={ACTION} DRY_RUN={not SHOULD_MUTATE} STATUS={STATUS} Item={item_name}&quot;)
#
# # Final fallback for answer_text if it hasn&#x27;t been set by specific success/error branches
# if not answer_text:
#     if STATUS == &quot;invalid_request&quot;:
#         answer_text = &quot;I&#x27;m sorry, I couldn&#x27;t understand your request to return an item. Please specify the quantity and the exact item name.&quot;
#     elif STATUS == &quot;unsupported_intent&quot;:
#         answer_text = &quot;I can only process purchases or returns for items currently in our inventory.&quot;
#     elif STATUS == &quot;no_match&quot;: # Should have been set above, but for robustness
#         answer_text = &quot;I couldn&#x27;t find any matching items for your request.&quot;
#
# &lt;/execute_python&gt;</code></pre></div>

# %% [markdown]
# Before we execute the plan, let’s check the current status of the transactions.

# %%
utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table Before Return")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table Before Return</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:44:01.482957&quot;
#   }
# ]</code></pre></div>

# %% [markdown]
# The transaction log currently shows a single entry — the opening balance (`TXN001`) for `$500.00` recorded at `2025-10-03T09:16:59.628898`.
#
# Ready to go—execute the plan by running the cell below.

# %%
# Execute the generated plan for the round-sunglasses question
result = execute_generated_code(
    full_content_aviator,          # the full LLM response you generated earlier
    db=db,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    user_request=prompt_aviator, # e.g., "Return 2 aviator sunglasses I bought last week."
)

# Peek at exactly what Python the plan executed
utils.print_html(result["answer"], title="Plan Execution · Extracted Answer")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan Execution · Extracted Answer</div><pre><code>None</code></pre></div>

# %% [markdown]
# You can see below that a new transaction has been inserted for the Aviator sunglasses return.

# %%
utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table After Return")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table After Return</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:44:01.482957&quot;
#   }
# ]</code></pre></div>

# %% [markdown]
# And by running the cell below, you’ll see the Aviator stock increase to 25 (`quantity_in_stock`).

# %%
Item = Query()                  

aviators = inventory_tbl.search(
    (Item.name == "Aviator")
)

utils.print_html(json.dumps(aviators, indent=2), title="Inventory status: Aviator sunglasses after return")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory status: Aviator sunglasses after return</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 23,
#     &quot;price&quot;: 80
#   }
# ]</code></pre></div>

# %% [markdown]
# ## 3. Putting It All Together: Customer Service Agent
#
# You’ve built the pieces—schema, prompt, code generator, and executor. Now let’s wire them up into a single helper that takes a natural-language request, generates a plan-as-code, executes it safely, and shows the result (plus before/after tables).
#
# **What this agent does**
# - Optionally reseeds the demo data for a clean run.
# - Generates the plan (Python inside `<execute_python>…</execute_python>`).
# - Executes the plan in a controlled namespace (TinyDB + helpers).
# - Surfaces a concise `answer_text` and renders before/after snapshots.

# %%
def customer_service_agent(
    question: str,
    *,
    db,
    inventory_tbl,
    transactions_tbl,
    model: str = "gemini-2.5-flash",
    temperature: float = 1.0,
    reseed: bool = False,
) -> dict:
    """
    End-to-end helper:
      1) (Optional) reseed inventory & transactions
      2) Generate plan-as-code from `question`
      3) Execute in a controlled namespace
      4) Render before/after snapshots and return artifacts

    Returns:
      {
        "full_content": <raw LLM response (may include <execute_python> tags)>,
        "exec": {
            "code": <extracted python>,
            "stdout": <plan logs>,
            "error": <traceback or None>,
            "answer": <answer_text/rows/json>,
            "inventory_after": [...],
            "transactions_after": [...]
        }
      }
    """
    # 0) Optional reseed
    if reseed:
        inv_utils.create_inventory()
        inv_utils.create_transactions()

    # 1) Show the question
    utils.print_html(question, title="User Question")

    # 2) Generate plan-as-code (FULL content)
    full_content = generate_llm_code(
        question,
        inventory_tbl=inventory_tbl,
        transactions_tbl=transactions_tbl,
        model=model,
        temperature=temperature,
    )
    utils.print_html(full_content, title="Plan with Code (Full Response)")

    # 3) Before snapshots
    utils.print_html(json.dumps(inventory_tbl.all(), indent=2), title="Inventory Table · Before")
    utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table · Before")

    # 4) Execute
    exec_res = execute_generated_code(
        full_content,
        db=db,
        inventory_tbl=inventory_tbl,
        transactions_tbl=transactions_tbl,
        user_request=question,
    )

    # 5) After snapshots + final answer
    utils.print_html(exec_res["answer"], title="Plan Execution · Extracted Answer")
    utils.print_html(json.dumps(inventory_tbl.all(), indent=2), title="Inventory Table · After")
    utils.print_html(json.dumps(transactions_tbl.all(), indent=2), title="Transactions Table · After")

    # 6) Return artifacts
    return {
        "full_content": full_content,
        "exec": {
            "code": exec_res["code"],
            "stdout": exec_res["stdout"],
            "error": exec_res["error"],
            "answer": exec_res["answer"],
            "inventory_after": inventory_tbl.all(),
            "transactions_after": transactions_tbl.all(),
        },
    }

# %% [markdown]
# ## 4. Try It Out (with the Customer Service Agent)
#
# Use the `customer_service_agent(...)` helper to go from a natural-language request → plan-as-code → safe execution → before/after snapshots.
#
# **Try these prompts:**
# 1) **Read-only (Andrew’s example):**
#    “Do you have any round sunglasses in stock that are under $100?”
# 2) **Mutation — return:**
#    “Return 2 Aviator sunglasses.”
# 3) **Mutation — purchase:**
#    “Purchase 3 Wayfarer sunglasses for customer Alice.”
# 4) **Mutation - purchase multiple items:**
#    "I want to buy 3 pairs of classic sunglasses and 1 pair of aviator."
#
#
# <div style="border:1px solid #93c5fd; border-left:6px solid #3b82f6; background:#eff6ff; border-radius:8px; padding:14px 16px; color:#1e3a8a; font-family:system-ui,-apple-system,Segoe UI,Roboto,Ubuntu,Cantarell,Noto Sans,sans-serif;">
#   🔎 <strong>What does <code>reseed=True</code> do?</strong><br><br>
#   When you call <code>customer_service_agent(..., reseed=True)</code>, the agent <em>re-initializes</em> the demo data before running your prompt:
#   <ul style="margin:8px 0 0 18px;">
#     <li><strong>Resets</strong> the <code>inventory_tbl</code> to the default product set.</li>
#     <li><strong>Resets</strong> the <code>transactions_tbl</code> to a single opening-balance entry.</li>
#     <li>Ensures a <strong>clean, reproducible</strong> run so results aren’t affected by previous tests.</li>
#   </ul>
#   Set <code>reseed=False</code> if you want to <strong>preserve</strong> the current state and continue from prior operations.
# </div>

# %% [markdown]
# ### Test 1

# %%
prompt = "I want to buy 3 pairs of classic sunglasses and 1 pair of aviator sunglasses."

out = customer_service_agent(
    prompt,
    db=db,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    model="gemini-2.5-flash",
    temperature=1.0,
    reseed=True,   # set False to keep current state of the inventory and the transactions
)
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">User Question</div><pre><code>I want to buy 3 pairs of classic sunglasses and 1 pair of aviator sunglasses.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan with Code (Full Response)</div><pre><code>&lt;execute_python&gt;
# import re
# from datetime import datetime
# from tinydb import Query
#
# # Initialize response variables
# answer_text = &quot;&quot;
# STATUS = &quot;invalid_request&quot;
# ACTION = &quot;read&quot;
# SHOULD_MUTATE = False
#
# # 1. Parse intent &amp; constraints from user_request
# purchase_requests = []
# # Regex to find patterns like &quot;3 pairs of classic sunglasses&quot; or &quot;1 pair of aviator&quot;
# # Captures quantity (group 1) and item name (group 2)
# item_pattern = re.compile(r&#x27;(\d+)\s+pair(?:s)?\s+of\s+([a-zA-Z]+)(?:\s+sunglasses)?&#x27;, re.IGNORECASE)
# matches = item_pattern.findall(user_request)
#
# if matches:
#     SHOULD_MUTATE = True
#     ACTION = &quot;mutate&quot;
#     for match in matches:
#         try:
#             quantity = int(match[0])
#             item_name = match[1].strip()
#             purchase_requests.append({&#x27;name&#x27;: item_name, &#x27;quantity&#x27;: quantity})
#         except ValueError:
#             # Fallback if quantity parsing fails (unlikely with current regex)
#             pass
#
# if not purchase_requests:
#     answer_text = &quot;I couldn&#x27;t understand what items and quantities you&#x27;d like to purchase. Could you please specify?&quot;
#     STATUS = &quot;invalid_request&quot;
# else:
#     # 2. Build TinyDB condition incrementally; query inventory_tbl.
#     #    Pre-check for stock availability for all items before any mutation.
#     ready_to_mutate = True
#     pre_checked_items = []
#     issues = []
#
#     Item = Query()
#     for req in purchase_requests:
#         item_name_to_find = req[&#x27;name&#x27;]
#         requested_quantity = req[&#x27;quantity&#x27;]
#
#         # Find the item in the inventory, case-insensitively using regex matching
#         found_items = inventory_tbl.search(Item.name.matches(item_name_to_find, flags=re.IGNORECASE))
#
#         if not found_items:
#             ready_to_mutate = False
#             STATUS = &quot;no_match&quot;
#             answer_text = f&quot;I couldn’t find an item named &#x27;{item_name_to_find}&#x27; in our inventory.&quot;
#             break # Exit early if any item is not found
#
#         # Assuming the first match is the intended item for simplicity, as item names are distinct per sample.
#         item_doc = found_items[0]
#
#         if item_doc[&#x27;quantity_in_stock&#x27;] &lt; requested_quantity:
#             ready_to_mutate = False
#             STATUS = &quot;insufficient_stock&quot;
#             issues.append(f&quot;We only have {item_doc[&#x27;quantity_in_stock&#x27;]} pair(s) of {item_doc[&#x27;name&#x27;]} left.&quot;)
#             # Do not break, collect all insufficient stock messages
#
#         pre_checked_items.append({
#             &#x27;doc_id&#x27;: item_doc.doc_id,
#             &#x27;item_id&#x27;: item_doc[&#x27;item_id&#x27;],
#             &#x27;name&#x27;: item_doc[&#x27;name&#x27;],
#             &#x27;price&#x27;: item_doc[&#x27;price&#x27;],
#             &#x27;requested_quantity&#x27;: requested_quantity,
#             &#x27;current_stock&#x27;: item_doc[&#x27;quantity_in_stock&#x27;]
#         })
#
#     if not ready_to_mutate:
#         if STATUS == &quot;insufficient_stock&quot;:
#             answer_text = &quot; &quot;.join(issues) + &quot; Would you like to adjust your order?&quot;
#         # If STATUS is &quot;no_match&quot;, answer_text is already set
#     else:
#         # All checks passed, proceed with mutations
#         current_balance = get_current_balance(transactions_tbl)
#         transaction_summaries = []
#         customer_name = &quot;Online Customer&quot; # Customer name not in request, using a default
#
#         for item_data in pre_checked_items:
#             doc_id = item_data[&#x27;doc_id&#x27;]
#             item_id = item_data[&#x27;item_id&#x27;]
#             item_name = item_data[&#x27;name&#x27;]
#             requested_quantity = item_data[&#x27;requested_quantity&#x27;]
#             item_price = item_data[&#x27;price&#x27;]
#
#             # Update inventory_tbl (decrement stock)
#             new_stock = item_data[&#x27;current_stock&#x27;] - requested_quantity
#             inventory_tbl.update({&#x27;quantity_in_stock&#x27;: new_stock}, doc_ids=[doc_id])
#
#             # Calculate transaction details for this line item
#             line_total = item_price * requested_quantity
#             current_balance += line_total # Update balance sequentially for each transaction
#
#             # Insert transaction into transactions_tbl for this individual item
#             new_txn_id = next_transaction_id(transactions_tbl)
#             transactions_tbl.insert({
#                 &#x27;transaction_id&#x27;: new_txn_id,
#                 &#x27;customer_name&#x27;: customer_name,
#                 &#x27;transaction_summary&#x27;: f&quot;Purchase {requested_quantity} x {item_name} ({item_id})&quot;,
#                 &#x27;transaction_amount&#x27;: float(line_total),
#                 &#x27;balance_after_transaction&#x27;: float(current_balance),
#                 &#x27;timestamp&#x27;: datetime.now().isoformat()
#             })
#             transaction_summaries.append(f&quot;{requested_quantity} {item_name}&quot;)
#
#         STATUS = &quot;success&quot;
#         if len(transaction_summaries) == 1:
#             answer_text = f&quot;Your purchase of {transaction_summaries[0]} has been successfully processed.&quot;
#         elif len(transaction_summaries) &gt; 1:
#             # Construct a human-friendly list for multiple items
#             last_item_summary = transaction_summaries.pop()
#             answer_text = f&quot;Your purchases of {&#x27;, &#x27;.join(transaction_summaries)} and {last_item_summary} have been successfully processed.&quot;
#         else:
#             answer_text = &quot;Your order was processed successfully.&quot; # Fallback, should not be reached if pre_checked_items is not empty
#
# # Print log to stdout
# print(f&quot;LOG: ACTION={ACTION} SHOULD_MUTATE={SHOULD_MUTATE} STATUS={STATUS}&quot;)
# &lt;/execute_python&gt;</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table · Before</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 23,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table · Before</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:50:11.518213&quot;
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan Execution · Extracted Answer</div><pre><code>Your purchases of 3 Classic and 1 Aviator have been successfully processed.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table · After</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 22,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 7,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table · After</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:50:11.518213&quot;
#   },
#   {
#     &quot;transaction_id&quot;: &quot;TXN002&quot;,
#     &quot;customer_name&quot;: &quot;Online Customer&quot;,
#     &quot;transaction_summary&quot;: &quot;Purchase 3 x Classic (SG005)&quot;,
#     &quot;transaction_amount&quot;: 180.0,
#     &quot;balance_after_transaction&quot;: 680.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:50:31.919772&quot;
#   },
#   {
#     &quot;transaction_id&quot;: &quot;TXN003&quot;,
#     &quot;customer_name&quot;: &quot;Online Customer&quot;,
#     &quot;transaction_summary&quot;: &quot;Purchase 1 x Aviator (SG001)&quot;,
#     &quot;transaction_amount&quot;: 80.0,
#     &quot;balance_after_transaction&quot;: 760.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:50:31.923841&quot;
#   }
# ]</code></pre></div>

# %% [markdown]
# ### Test 2

# %%
Item = Query()                    # Create a Query object to reference fields (e.g., Item.name, Item.description)

# Query: fetch all inventory rows whose 'name' is exactly "Aviator".
# Notes:
# - This is a case-sensitive equality check. "aviator" won't match.
# - If you need case-insensitive matching, consider a .test(...) or .matches(...) with re.I.
aviators = inventory_tbl.search(
    (Item.name == "Aviator")
)

# Display the matched documents in a readable JSON panel
utils.print_html(json.dumps(aviators, indent=2), title="Inventory status: Aviator sunglasses before return")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory status: Aviator sunglasses before return</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 22,
#     &quot;price&quot;: 80
#   }
# ]</code></pre></div>

# %%
prompt = "I want to return 2 Aviator sunglasses I bought last week."

out = customer_service_agent(
    prompt,
    db=db,
    inventory_tbl=inventory_tbl,
    transactions_tbl=transactions_tbl,
    model="gemini-2.5-flash",
    temperature=1.0,
    reseed=True,   # set False to keep current state of the inventory and the transactions
)
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">User Question</div><pre><code>I want to return 2 Aviator sunglasses I bought last week.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan with Code (Full Response)</div><pre><code>&lt;execute_python&gt;
# from tinydb import Query
# from datetime import datetime
# import re
#
# # Initialize variables based on user request and system context
# # (These would typically be passed in, but are set here for planning purposes)
# # db, inventory_tbl, transactions_tbl are TinyDB Table objects provided by the environment.
# # get_current_balance(tbl) -&gt; float and next_transaction_id(tbl, prefix=&quot;TXN&quot;) -&gt; str are helper functions.
# # user_request: str is the original user message.
#
# Item = Query()
#
# # 1. Parse intent and constraints from user_request
# SHOULD_MUTATE = False
# ACTION = &quot;read&quot; # Default action
# STATUS = &quot;invalid_request&quot; # Default status, will be updated
# answer_text = &quot;&quot;
# log_message = &quot;&quot;
#
# # Regex to extract quantity and item name for a return request
# return_pattern = re.search(r&quot;return (\d+)\s+(.+?)(?:\s+sunglasses)?&quot;, user_request, re.IGNORECASE)
#
# if return_pattern:
#     ACTION = &quot;mutate&quot;
#     SHOULD_MUTATE = True
#     quantity_to_return = int(return_pattern.group(1))
#     item_name_to_return = return_pattern.group(2).strip()
#
#     log_message = f&quot;LOG: ACTION={ACTION} SHOULD_MUTATE={SHOULD_MUTATE} Intent=return Item=&#x27;{item_name_to_return}&#x27; Quantity={quantity_to_return}&quot;
#
#     # 2. Query inventory_tbl for the specified item
#     # Using .search with .test for more flexible matching, or .matches if full string match is desired.
#     # Given example names, .search is good for partial matches if needed, but .test with lower() for exact might be better.
#     # For now, let&#x27;s stick with .search() to be flexible, assuming user name maps directly to inventory.name
#     item_record = inventory_tbl.search(Item.name.matches(item_name_to_return, flags=re.IGNORECASE))
#
#     if item_record:
#         # Assuming item_name is unique or we take the first match
#         item_data = item_record[0]
#         item_id = item_data[&#x27;item_id&#x27;]
#         current_stock = item_data[&#x27;quantity_in_stock&#x27;]
#         item_price = item_data[&#x27;price&#x27;]
#
#         # Calculate the financial impact of the return
#         # Transaction amount for a return is negative (money goes out of the register)
#         transaction_amount = - (item_price * quantity_to_return)
#
#         # Get current balance before this transaction
#         current_register_balance = get_current_balance(transactions_tbl)
#
#         # Calculate new balance after this specific transaction
#         new_register_balance = current_register_balance + transaction_amount
#
#         # 3. Perform mutation: Update inventory and record transaction
#         if SHOULD_MUTATE:
#             # Update inventory: add the returned quantity to stock
#             new_stock = current_stock + quantity_to_return
#             inventory_tbl.update({&#x27;quantity_in_stock&#x27;: new_stock}, Item.item_id == item_id)
#
#             # Record the transaction
#             new_txn_id = next_transaction_id(transactions_tbl)
#             timestamp = datetime.now().isoformat()
#             transaction_summary = f&quot;Customer Return: {quantity_to_return} x {item_name_to_return} (Item ID: {item_id})&quot;
#
#             transactions_tbl.insert({
#                 &#x27;transaction_id&#x27;: new_txn_id,
#                 &#x27;customer_name&#x27;: &#x27;Customer Return&#x27;,
#                 &#x27;transaction_summary&#x27;: transaction_summary,
#                 &#x27;transaction_amount&#x27;: transaction_amount,
#                 &#x27;balance_after_transaction&#x27;: new_register_balance,
#                 &#x27;timestamp&#x27;: timestamp
#             })
#
#             STATUS = &quot;success&quot;
#             answer_text = (
#                 f&quot;Successfully processed the return of {quantity_to_return} {item_name_to_return} sunglasses. &quot;
#                 f&quot;There are now {new_stock} in stock, and your account balance has been updated.&quot;
#             )
#             log_message += (
#                 f&quot; STATUS={STATUS} ItemID={item_id} OldStock={current_stock} NewStock={new_stock} &quot;
#                 f&quot;ReturnAmount=${-transaction_amount:.2f} NewBalance=${new_register_balance:.2f}&quot;
#             )
#         else:
#             # This block would execute if SHOULD_MUTATE was set to False, for a dry run scenario.
#             # However, for a return, we always intend to mutate if parsed successfully.
#             # Keeping it structured for completeness based on general planning rules.
#             STATUS = &quot;success&quot; # Still considered successful in finding the item for the dry run
#             answer_text = (
#                 f&quot;DRY RUN: We would process the return of {quantity_to_return} {item_name_to_return} sunglasses. &quot;
#                 f&quot;This would add {quantity_to_return} to stock and reduce the register balance by ${-transaction_amount:.2f}.&quot;
#             )
#             log_message += (
#                 f&quot; DRY_RUN=True STATUS={STATUS} ItemID={item_id} OldStock={current_stock} &quot;
#                 f&quot;ProposedNewStock={current_stock + quantity_to_return} ProposedReturnAmount=${-transaction_amount:.2f} &quot;
#                 f&quot;ProposedNewBalance=${new_register_balance:.2f}&quot;
#             )
#     else:
#         # Item not found in inventory
#         STATUS = &quot;no_match&quot;
#         answer_text = (
#             f&quot;We couldn&#x27;t find &#x27;{item_name_to_return}&#x27; sunglasses in our inventory. &quot;
#             f&quot;Please check the name or consider another style.&quot;
#         )
#         log_message += f&quot; STATUS={STATUS} Reason=&#x27;Item not found: {item_name_to_return}&#x27;&quot;
#
# else:
#     # Unable to parse the return request (missing quantity or item name)
#     STATUS = &quot;invalid_request&quot;
#     answer_text = &quot;I couldn&#x27;t understand the item or quantity for the return. Please specify how many of which item you&#x27;d like to return.&quot;
#     log_message += f&quot; STATUS={STATUS} Reason=&#x27;Failed to parse return details from: {user_request}&#x27;&quot;
#
# # Print log message for internal use (stdout)
# print(log_message)
#
# # The &#x27;answer_text&#x27; variable holds the final human-readable response.
# # The &#x27;STATUS&#x27; variable holds the outcome status.
# &lt;/execute_python&gt;</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table · Before</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 23,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table · Before</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:54:07.171483&quot;
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Plan Execution · Extracted Answer</div><pre><code>Successfully processed the return of 2 A sunglasses. There are now 25 in stock, and your account balance has been updated.</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory Table · After</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 25,
#     &quot;price&quot;: 80
#   },
#   {
#     &quot;item_id&quot;: &quot;SG002&quot;,
#     &quot;name&quot;: &quot;Wayfarer&quot;,
#     &quot;description&quot;: &quot;Featuring thick, angular frames that make a statement, these sunglasses combine retro charm with modern edge. The rectangular lenses and sturdy acetate construction create a confident look.&quot;,
#     &quot;quantity_in_stock&quot;: 6,
#     &quot;price&quot;: 95
#   },
#   {
#     &quot;item_id&quot;: &quot;SG003&quot;,
#     &quot;name&quot;: &quot;Mystique&quot;,
#     &quot;description&quot;: &quot;Inspired by 1950s glamour, these frames sweep upward at the outer corners to create an elegant, feminine silhouette. The subtle curves and often embellished temples add sophistication to any outfit.&quot;,
#     &quot;quantity_in_stock&quot;: 3,
#     &quot;price&quot;: 70
#   },
#   {
#     &quot;item_id&quot;: &quot;SG004&quot;,
#     &quot;name&quot;: &quot;Sport&quot;,
#     &quot;description&quot;: &quot;Designed for active lifestyles, these wraparound sunglasses feature a single curved lens that provides maximum coverage and wind protection. The lightweight, flexible frames include rubber grips.&quot;,
#     &quot;quantity_in_stock&quot;: 11,
#     &quot;price&quot;: 110
#   },
#   {
#     &quot;item_id&quot;: &quot;SG005&quot;,
#     &quot;name&quot;: &quot;Classic&quot;,
#     &quot;description&quot;: &quot;Classic round profile with minimalist metal frames, offering a timeless and versatile style that fits both casual and formal wear.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 60
#   },
#   {
#     &quot;item_id&quot;: &quot;SG006&quot;,
#     &quot;name&quot;: &quot;Moon&quot;,
#     &quot;description&quot;: &quot;Oversized round style with bold plastic frames, evoking retro aesthetics with a modern twist.&quot;,
#     &quot;quantity_in_stock&quot;: 10,
#     &quot;price&quot;: 120
#   }
# ]</code></pre></div>
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Transactions Table · After</div><pre><code>[
#   {
#     &quot;transaction_id&quot;: &quot;TXN001&quot;,
#     &quot;customer_name&quot;: &quot;OPENING_BALANCE&quot;,
#     &quot;transaction_summary&quot;: &quot;Daily opening register balance&quot;,
#     &quot;transaction_amount&quot;: 500.0,
#     &quot;balance_after_transaction&quot;: 500.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:54:07.171483&quot;
#   },
#   {
#     &quot;transaction_id&quot;: &quot;TXN002&quot;,
#     &quot;customer_name&quot;: &quot;Customer Return&quot;,
#     &quot;transaction_summary&quot;: &quot;Customer Return: 2 x A (Item ID: SG001)&quot;,
#     &quot;transaction_amount&quot;: -160,
#     &quot;balance_after_transaction&quot;: 340.0,
#     &quot;timestamp&quot;: &quot;2025-12-21T17:54:25.381450&quot;
#   }
# ]</code></pre></div>

# %%
Item = Query()                    # Create a Query object to reference fields (e.g., Item.name, Item.description)

# Query: fetch all inventory rows whose 'name' is exactly "Aviator".
# Notes:
# - This is a case-sensitive equality check. "aviator" won't match.
# - If you need case-insensitive matching, consider a .test(...) or .matches(...) with re.I.
aviators = inventory_tbl.search(
    (Item.name == "Aviator")
)

# Display the matched documents in a readable JSON panel
utils.print_html(json.dumps(aviators, indent=2), title="Inventory status: Aviator sunglasses before return")
# Out:
#     <style>
#     .pretty-card{
#       font-family: ui-sans-serif, system-ui;
#       border: 2px solid transparent;
#       border-radius: 14px;
#       padding: 14px 16px;
#       margin: 10px 0;
#       background: linear-gradient(#fff, #fff) padding-box,
#                   linear-gradient(135deg, #3b82f6, #9333ea) border-box;
#       color: #111;
#       box-shadow: 0 4px 12px rgba(0,0,0,.08);
#     }
#     .pretty-title{
#       font-weight:700;
#       margin-bottom:8px;
#       font-size:14px;
#       color:#111;
#     }
#     /* 🔒 Solo afecta lo DENTRO de la tarjeta */
#     .pretty-card pre,
#     .pretty-card code {
#       background: #f3f4f6;
#       color: #111;
#       padding: 8px;
#       border-radius: 8px;
#       display: block;
#       overflow-x: auto;
#       font-size: 13px;
#       white-space: pre-wrap;
#     }
#     .pretty-card img { max-width: 100%; height: auto; border-radius: 8px; }
#     .pretty-card table.pretty-table {
#       border-collapse: collapse;
#       width: 100%;
#       font-size: 13px;
#       color: #111;
#     }
#     .pretty-card table.pretty-table th,
#     .pretty-card table.pretty-table td {
#       border: 1px solid #e5e7eb;
#       padding: 6px 8px;
#       text-align: left;
#     }
#     .pretty-card table.pretty-table th { background: #f9fafb; font-weight: 600; }
#     </style>
#     <div class="pretty-card"><div class="pretty-title">Inventory status: Aviator sunglasses before return</div><pre><code>[
#   {
#     &quot;item_id&quot;: &quot;SG001&quot;,
#     &quot;name&quot;: &quot;Aviator&quot;,
#     &quot;description&quot;: &quot;Originally designed for pilots, these teardrop-shaped lenses with thin metal frames offer timeless appeal. The large lenses provide excellent coverage while the lightweight construction ensures comfort during long wear.&quot;,
#     &quot;quantity_in_stock&quot;: 25,
#     &quot;price&quot;: 80
#   }
# ]</code></pre></div>

# %% [markdown]
# ## 5. Takeaways
#
# - **You let code be the plan.** Following Andrew’s “code-as-action” idea, you had the model write Python that chains the steps (filter → compute → update) and then you just ran it.
#
# - **You skipped the brittle tool soup.** Instead of piling on tiny tools or JSON plans, you used Python/TinyDB—giving the model a big, familiar toolbox that handles many query shapes with one prompt.
#
# - **You kept runs safe and visible.** You executed in a controlled namespace, captured logs/errors, and reviewed before/after tables—so you always know what changed and why.

# %% [markdown]
# <div style="border:1px solid #22c55e; border-left:6px solid #16a34a; background:#dcfce7; border-radius:6px; padding:14px 16px; color:#064e3b; font-family:system-ui,-apple-system,Segoe UI,Roboto,Ubuntu,Cantarell,Noto Sans,sans-serif;">
#
# 🎉 <strong>Congratulations!</strong>
#
# You just finished the lab and built an <em>agentic</em> customer service workflow. You let the model write code as the plan, ran it safely, and used simple validations to keep updates reliable. When things failed, you surfaced clear, human-readable reasons; when things worked, you saw exactly what changed via before/after snapshots.
#
# With this pattern—planning <em>in</em> code, plus transparent execution—you’re ready to design your own workflows that feel automatic, safe, and easy to extend. 🚀
#
# </div>
